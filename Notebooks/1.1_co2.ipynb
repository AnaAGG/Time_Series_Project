# %%
import sys
sys.path.append('../')

import pandas as pd

import src.cleaning as cl

# %% [markdown]
# https://towardsdatascience.com/time-series-analysis-and-climate-change-7bb4371021e

# %%
co2 = pd.read_csv("../Data/co2.csv", sep = ";")
co2.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   2019-03-21
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                Unnamed: 2      Unnamed: 3  Unnamed: 4  \
# 0                                     NaN             NaN         NaN
# 1                                     NaN             NaN         NaN
# 2                                     NaN             NaN         NaN
# 3                          Indicator Name  Indicator Code      1960.0
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2         NaN         NaN         NaN         NaN         NaN  ...
# 3      1961.0      1962.0      1963.0      1964.0      1965.0  ...
# 4         NaN         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  2010.000000  2011.000000  2012.000000  2013.000000  2014.000000
# 4    24.670529    24.505835    13.155542     8.351294     8.408363
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3       2015.0       2016.0       2017.0       2018.0          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 64 columns]

# %%
df = cl.cleaning_co2_data(co2)

# %%
df.head(2)
# Out:
#   Country Name Country Code                          Indicator Name  \
# 4        Aruba          ABW  CO2 emissions (metric tons per capita)
# 5  Afghanistan          AFG  CO2 emissions (metric tons per capita)
#
#    Indicator Code     1960      1961      1962      1963      1964      1965  \
# 4  EN.ATM.CO2E.PC      NaN       NaN       NaN       NaN       NaN       NaN
# 5  EN.ATM.CO2E.PC  0.04606  0.053604  0.073765  0.074233  0.086292  0.101467
#
#    ...       2005       2006       2007       2008       2009       2010  \
# 4  ...  27.200708  26.948260  27.895574  26.230847  25.915833  24.670529
# 5  ...   0.052948   0.063728   0.085418   0.154101   0.241723   0.293837
#
#         2011       2012      2013      2014
# 4  24.505835  13.155542  8.351294  8.408363
# 5   0.412017   0.350371  0.315602  0.299445
#
# [2 rows x 59 columns]
